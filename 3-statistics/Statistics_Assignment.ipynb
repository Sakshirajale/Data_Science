# %%
#read csv file
import pandas as pd
df=pd.read_csv("C:/7-Clustering/crime_data.csv.xls")
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
df.iloc[:5,:7]
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
#Display category of Murder
set(df['Murder'])
# Out:
# {0.8,
#  2.1,
#  2.2,
#  2.6,
#  2.7,
#  3.2,
#  3.3,
#  3.4,
#  3.8,
#  4.0,
#  4.3,
#  4.4,
#  4.9,
#  5.3,
#  5.7,
#  5.9,
#  6.0,
#  6.3,
#  6.6,
#  6.8,
#  7.2,
#  7.3,
#  7.4,
#  7.9,
#  8.1,
#  8.5,
#  8.8,
#  9.0,
#  9.7,
#  10.0,
#  10.4,
#  11.1,
#  11.3,
#  11.4,
#  12.1,
#  12.2,
#  12.7,
#  13.0,
#  13.2,
#  14.4,
#  15.4,
#  16.1,
#  17.4}

# %%
set(df['Rape'])
# Out:
# {7.3,
#  7.8,
#  8.3,
#  9.3,
#  9.5,
#  10.8,
#  11.1,
#  11.2,
#  11.3,
#  12.8,
#  14.2,
#  14.9,
#  15.6,
#  15.8,
#  16.1,
#  16.3,
#  16.4,
#  16.5,
#  17.1,
#  18.0,
#  18.8,
#  19.5,
#  20.0,
#  20.2,
#  20.7,
#  21.0,
#  21.2,
#  21.4,
#  22.2,
#  22.5,
#  22.9,
#  24.0,
#  25.5,
#  25.8,
#  26.1,
#  26.2,
#  26.9,
#  27.8,
#  28.2,
#  29.3,
#  31.0,
#  31.9,
#  32.1,
#  35.1,
#  38.7,
#  40.6,
#  44.5,
#  46.0}

# %%
df.iloc[:5,2:4]
# Out:
#    Assault  UrbanPop
# 0      236        58
# 1      263        48
# 2      294        80
# 3      190        50
# 4      276        91

# %%
#display 4 column and 4 rows
df.iloc[:4,:4]
# Out:
#   Unnamed: 0  Murder  Assault  UrbanPop
# 0    Alabama    13.2      236        58
# 1     Alaska    10.0      263        48
# 2    Arizona     8.1      294        80
# 3   Arkansas     8.8      190        50

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/7-Clustering/crime_data.csv.xls",names=["Unnamed:0",	"Murder"	],skiprows=[0])
df
# Out:
#                          Unnamed:0  Murder
# Alabama        13.2 236         58    21.2
# Alaska         10.0 263         48    44.5
# Arizona        8.1  294         80    31.0
# Arkansas       8.8  190         50    19.5
# California     9.0  276         91    40.6
# Colorado       7.9  204         78    38.7
# Connecticut    3.3  110         77    11.1
# Delaware       5.9  238         72    15.8
# Florida        15.4 335         80    31.9
# Georgia        17.4 211         60    25.8
# Hawaii         5.3  46          83    20.2
# Idaho          2.6  120         54    14.2
# Illinois       10.4 249         83    24.0
# Indiana        7.2  113         65    21.0
# Iowa           2.2  56          57    11.3
# Kansas         6.0  115         66    18.0
# Kentucky       9.7  109         52    16.3
# Louisiana      15.4 249         66    22.2
# Maine          2.1  83          51     7.8
# Maryland       11.3 300         67    27.8
# Massachusetts  4.4  149         85    16.3
# ...

# %%
df.Murder.describe()
# Out:
# count    50.000000
# mean     21.232000
# std       9.366385
# min       7.300000
# 25%      15.075000
# 50%      20.100000
# 75%      26.175000
# max      46.000000
# Name: Murder, dtype: float64

# %%
df.Murder.quantile(0)
# Out:
# 7.3

# %%
df.Murder.quantile(0.25)
# Out:
# 15.075

# %%
df.Murder.quantile(0.75)
# Out:
# 26.175

# %%
df.Murder.quantile(1)
# Out:
# 46.0

# %%
#removing outlayer value
percentile_99=df.Murder.quantile(0.99)
percentile_99
# Out:
# 45.265

# %%
df_no_outlier=df[df.Murder<=percentile_99]
df_no_outlier
# Out:
#                          Unnamed:0  Murder
# Alabama        13.2 236         58    21.2
# Alaska         10.0 263         48    44.5
# Arizona        8.1  294         80    31.0
# Arkansas       8.8  190         50    19.5
# California     9.0  276         91    40.6
# Colorado       7.9  204         78    38.7
# Connecticut    3.3  110         77    11.1
# Delaware       5.9  238         72    15.8
# Florida        15.4 335         80    31.9
# Georgia        17.4 211         60    25.8
# Hawaii         5.3  46          83    20.2
# Idaho          2.6  120         54    14.2
# Illinois       10.4 249         83    24.0
# Indiana        7.2  113         65    21.0
# Iowa           2.2  56          57    11.3
# Kansas         6.0  115         66    18.0
# Kentucky       9.7  109         52    16.3
# Louisiana      15.4 249         66    22.2
# Maine          2.1  83          51     7.8
# Maryland       11.3 300         67    27.8
# Massachusetts  4.4  149         85    16.3
# ...

# %%
df.Murder[3]=np.NaN
df
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18120\3724241303.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Murder[3]=np.NaN
# C:\Users\ACER\AppData\Local\Temp\ipykernel_18120\3724241303.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df.Murder[3]=np.NaN
#                          Unnamed:0  Murder
# Alabama        13.2 236         58    21.2
# Alaska         10.0 263         48    44.5
# Arizona        8.1  294         80    31.0
# Arkansas       8.8  190         50     NaN
# California     9.0  276         91    40.6
# Colorado       7.9  204         78    38.7
# ...

# %%
#calculate mean value
df.Murder.mean()
# Out:
# 21.267346938775507

# %%
df_new=df.fillna(df.Murder.mean())
df_new
# Out:
#                          Unnamed:0     Murder
# Alabama        13.2 236         58  21.200000
# Alaska         10.0 263         48  44.500000
# Arizona        8.1  294         80  31.000000
# Arkansas       8.8  190         50  21.267347
# California     9.0  276         91  40.600000
# Colorado       7.9  204         78  38.700000
# Connecticut    3.3  110         77  11.100000
# Delaware       5.9  238         72  15.800000
# Florida        15.4 335         80  31.900000
# Georgia        17.4 211         60  25.800000
# Hawaii         5.3  46          83  20.200000
# Idaho          2.6  120         54  14.200000
# Illinois       10.4 249         83  24.000000
# Indiana        7.2  113         65  21.000000
# Iowa           2.2  56          57  11.300000
# Kansas         6.0  115         66  18.000000
# Kentucky       9.7  109         52  16.300000
# Louisiana      15.4 249         66  22.200000
# Maine          2.1  83          51   7.800000
# ...

# %%
#19-07-2024
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/7-Clustering/crime_data.csv.xls")
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
set(df['Assault'])
# Out:
# {45,
#  46,
#  48,
#  53,
#  56,
#  57,
#  72,
#  81,
#  83,
#  86,
#  102,
#  106,
#  109,
#  110,
#  113,
#  115,
#  120,
#  145,
#  149,
#  151,
#  156,
#  159,
#  161,
#  174,
#  178,
#  188,
#  190,
#  201,
#  204,
#  211,
#  236,
#  238,
#  249,
#  252,
#  254,
#  255,
#  259,
#  263,
#  276,
#  279,
#  285,
#  294,
#  300,
#  335,
#  337}

# %%
df['Assault'].describe()
# Out:
# count     50.000000
# mean     170.760000
# std       83.337661
# min       45.000000
# 25%      109.000000
# 50%      159.000000
# 75%      249.000000
# max      337.000000
# Name: Assault, dtype: float64

# %%
df['Assault'].plot(kind='hist', bins=20,color='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Murder'].plot(kind='hist', bins=20,color='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Assault'].plot(kind='kde',color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Murder'].plot(kind='kde',color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
#if value is 0 nearabout zero then almost normally distrubuted
df['Murder'].skew()
# Out:
# 0.3939564324470969

# %%
df['Murder'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Assault'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')
