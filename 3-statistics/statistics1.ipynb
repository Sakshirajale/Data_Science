# %%
#read csv file
import pandas as pd
df = pd.read_csv("C:/3-statistics/IPL IMB381IPL2013.csv.xls")
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.iloc[:5,:7]
#Nominal,Quantitative data-discreate data,nominal,nominal,continuous data
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63

# %%
#display category of age
set(df['AGE'])
# Out:
# {1, 2, 3}

# %%
set(df['T-RUNS'])
# Out:
# {0,
#  5,
#  11,
#  13,
#  16,
#  17,
#  51,
#  54,
#  58,
#  60,
#  63,
#  70,
#  74,
#  77,
#  83,
#  88,
#  107,
#  116,
#  120,
#  141,
#  146,
#  149,
#  199,
#  214,
#  249,
#  275,
#  281,
#  284,
#  288,
#  320,
#  380,
#  392,
#  432,
#  483,
#  491,
#  503,
#  537,
#  541,
#  544,
#  555,
#  556,
#  571,
#  624,
#  641,
#  654,
#  683,
#  699,
#  710,
#  770,
#  1000,
#  1105,
#  1114,
#  1219,
#  1261,
#  1269,
#  1451,
#  1462,
#  1546,
#  1586,
#  1606,
#  1716,
#  1775,
#  1780,
#  1944,
#  2164,
#  2173,
#  2200,
#  2506,
#  2648,
#  2742,
#  3089,
#  3154,
#  3509,
#  3712,
#  3763,
#  3781,
#  3845,
#  4188,
#  4486,
#  4722,
#  5457,
#  5515,
#  5570,
#  5708,
#  5842,
#  6167,
#  6373,
#  6398,
#  6654,
#  6973,
#  7172,
#  7212,
#  8042,
#  8178,
#  8625,
#  8781,
#  9382,
#  9918,
#  10440,
#  12379,
#  13218,
#  13288,
#  15470}

# %%
#display 5 rows and 7 to 13 column
df.iloc[:5,7:14]
#captaincy exp-->discrete data
#ramaining-->continous data
# Out:
#    T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP  RUNS-S
# 0       0           0      0.00         0        0.0              0       0
# 1      18         657     71.41       185       37.6              0       0
# 2      58        1269     80.62       288       32.9              0     167
# 3      31         241     84.56        51       36.8              0      58
# 4       0          79     45.93         0        0.0              0    1317

# %%
#display 5 column and 5 row
df.iloc[:5,:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM
# 0       1   Abdulla, YA    2      SA  KXIP
# 1       2  Abdur Razzak    2     BAN   RCB
# 2       3   Agarkar, AB    2     IND   KKR
# 3       4     Ashwin, R    1     IND   CSK
# 4       5  Badrinath, S    2     IND   CSK

# %%
#continuous in nature
df.iloc[:5,14:21]
# Out:
#    HS    AVE    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL
# 0   0   0.00    0.00       0     307    15   20.47
# 1   0   0.00    0.00       0      29     0    0.00
# 2  39  18.56  121.01       5    1059    29   36.52
# 3  11   5.80   76.32       0    1125    49   22.96
# 4  71  32.93  120.71      28       0     0    0.00

# %%
df.iloc[:5,21:] #continous in nature
# Out:
#     ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0   8.90  13.93          2009       50000       50000
# 1  14.50   0.00          2008       50000       50000
# 2   8.81  24.90          2008      200000      350000
# 3   6.23  22.14          2011      100000      850000
# 4   0.00   0.00          2011      100000      800000

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("C:/3-statistics/income.csv.xls", names=["name","income"], skiprows=[0])
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df = pd.read_csv("C:/3-statistics/income.csv.xls", names=["name","income"], skiprows=[0])
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df.income.describe()
# Out:
# count    7.000000e+00
# mean     1.433929e+06
# std      3.777283e+06
# min      4.000000e+03
# 25%      5.500000e+03
# 50%      7.000000e+03
# 75%      7.750000e+03
# max      1.000000e+07
# Name: income, dtype: float64

# %%
#18-07-2024
#0%
df.income.quantile(0)
# Out:
# 4000.0

# %%
#25%
df.income.quantile(0.25)
# Out:
# 5500.0

# %%
#75%
df.income.quantile(0.75)
# Out:
# 7750.0

# %%
#1%
df.income.quantile(1)
# Out:
# 10000000.0

# %%
#removing outlayer value
percentile_99=df.income.quantile(0.99)
percentile_99
# Out:
# 9400479.999999994

# %%
df_no_outlier=df[df.income<=percentile_99]
df_no_outlier
# Out:
#     name  income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %%
df
# Out:
#         name    income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
df.income[3]=np.NaN
#df['income'][3]=np.NaN
df
# Out:
#         name      income
# 0        Rob      5000.0
# 1      Rafiq      6000.0
# 2       Nina      4000.0
# 3      Sofia         NaN
# 4      Mohan      8000.0
# 5        Tao      7000.0
# 6  Elon Musk  10000000.0

# %%
#calculate mean value
df.income.mean()
# Out:
# 1671666.6666666667

# %%
df_new=df.fillna(df.income.mean())
df_new
# Out:
#         name        income
# 0        Rob  5.000000e+03
# 1      Rafiq  6.000000e+03
# 2       Nina  4.000000e+03
# 3      Sofia  1.671667e+06
# 4      Mohan  8.000000e+03
# 5        Tao  7.000000e+03
# 6  Elon Musk  1.000000e+07

# %%
#19-07-2024
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/3-statistics/train.csv.xls")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#column types
#*Numerical - age, fare,passengerld
#*Categorial - survived,Pclass,sex,Sibsp,Parch,Embarked
#*Mixed- Name, Ticket, Cabin
set(df['Pclass'])
# Out:
# {1, 2, 3}

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist', bins=20,color='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde',color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
#if value is 0 nearabout zero then almost normally distrubuted
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
#check null value in dataset
df['Age'].isnull().sum()
# Out:
# 177

# %%
#calculate percentage of null value
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# 0.19865319865319866

# %%
#Age
#CONCLUSIONS:-
#Age is normally (almost) distributed
#20% of the values are missing
#There are same outliers

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv("C:/3-statistics/iris.csv.xls")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Statistics==>
# Statistics is the science of collecting , organizing and analyzing data.
#
# Data==>
# Facts or pieces of information that can be measured.
#
# Types of statistics==>
# 1)Descriptive statistics
# Ex.84,86,73,65,80,81,92
# WHat is the avarage marks of the students.
#
# 2)Inferential statistics
# Ex.Are the marks of the students of this classroom similar to the age of the maths classroom in college.
